# %% [markdown]
# # Basics of Data Preprocessing

# %% [markdown]
# ## 1. Importing Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Data.csv")
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ### Creating Feature variable 'X'

# %%
X = dataset[['Country','Age','Salary']]
X
# Out:
#    Country   Age   Salary
# 0   France  44.0  72000.0
# 1    Spain  27.0  48000.0
# 2  Germany  30.0  54000.0
# 3    Spain  38.0  61000.0
# 4  Germany  40.0      NaN
# 5   France  35.0  58000.0
# 6    Spain   NaN  52000.0
# 7   France  48.0  79000.0
# 8  Germany  50.0  83000.0
# 9   France  37.0  67000.0

# %% [markdown]
# ### Create dependent variable 'y'

# %%
y = dataset[['Purchased']]
y
# Out:
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9       Yes

# %% [markdown]
# ## 2. Handling Missing Values

# %%
pd.isnull(X)
# Out:
#    Country    Age  Salary
# 0    False  False   False
# 1    False  False   False
# 2    False  False   False
# 3    False  False   False
# 4    False  False    True
# 5    False  False   False
# 6    False   True   False
# 7    False  False   False
# 8    False  False   False
# 9    False  False   False

# %%
X['Age'].fillna(X['Age'].mean() , inplace = True)
X
# Out:
# C:\Users\I339181\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#    Country        Age   Salary
# 0   France  44.000000  72000.0
# 1    Spain  27.000000  48000.0
# 2  Germany  30.000000  54000.0
# 3    Spain  38.000000  61000.0
# 4  Germany  40.000000      NaN
# 5   France  35.000000  58000.0
# 6    Spain  38.777778  52000.0
# 7   France  48.000000  79000.0
# 8  Germany  50.000000  83000.0
# 9   France  37.000000  67000.0

# %%
X['Salary'].fillna(X['Salary'].mean(),inplace = True)
X
# Out:
# C:\Users\I339181\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#    Country        Age        Salary
# 0   France  44.000000  72000.000000
# 1    Spain  27.000000  48000.000000
# 2  Germany  30.000000  54000.000000
# 3    Spain  38.000000  61000.000000
# 4  Germany  40.000000  63777.777778
# 5   France  35.000000  58000.000000
# 6    Spain  38.777778  52000.000000
# 7   France  48.000000  79000.000000
# 8  Germany  50.000000  83000.000000
# 9   France  37.000000  67000.000000

# %% [markdown]
# ### Handling missing values using Imputer class of sklearn

# %%
from sklearn.preprocessing import Imputer
X = dataset[['Country','Age','Salary']]
X
# Out:
#    Country   Age   Salary
# 0   France  44.0  72000.0
# 1    Spain  27.0  48000.0
# 2  Germany  30.0  54000.0
# 3    Spain  38.0  61000.0
# 4  Germany  40.0      NaN
# 5   France  35.0  58000.0
# 6    Spain   NaN  52000.0
# 7   France  48.0  79000.0
# 8  Germany  50.0  83000.0
# 9   France  37.0  67000.0

# %%
imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)

# %%
imputer = imputer.fit(X[['Age','Salary']])

# %%
X[['Age','Salary']] = imputer.transform(X[['Age','Salary']])
X
# Out:
# C:\Users\I339181\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\I339181\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#    Country        Age        Salary
# 0   France  44.000000  72000.000000
# 1    Spain  27.000000  48000.000000
# 2  Germany  30.000000  54000.000000
# 3    Spain  38.000000  61000.000000
# 4  Germany  40.000000  63777.777778
# 5   France  35.000000  58000.000000
# 6    Spain  38.777778  52000.000000
# 7   France  48.000000  79000.000000
# 8  Germany  50.000000  83000.000000
# 9   France  37.000000  67000.000000

# %% [markdown]
# # 3. Changing Categorical Data

# %% [markdown]
# ### Approach 1 : Find and Replace

# %% [markdown]
# ### Approach 2: Label Encoding

# %%
X['Country'] = X['Country'].astype('category')
X['Country_codes'] = X['Country'].cat.codes
X
# Out:
# C:\Users\I339181\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Country        Age        Salary  Country_codes
# 0   France  44.000000  72000.000000              0
# 1    Spain  27.000000  48000.000000              2
# 2  Germany  30.000000  54000.000000              1
# 3    Spain  38.000000  61000.000000              2
# 4  Germany  40.000000  63777.777778              1
# 5   France  35.000000  58000.000000              0
# 6    Spain  38.777778  52000.000000              2
# 7   France  48.000000  79000.000000              0
# 8  Germany  50.000000  83000.000000              1
# 9   France  37.000000  67000.000000              0

# %% [markdown]
# ### Approach 3: One Hot Encoding

# %%
pd.get_dummies(X, columns = ['Country_codes'])
# Out:
#    Country        Age        Salary  Country_codes_0  Country_codes_1  \
# 0   France  44.000000  72000.000000                1                0
# 1    Spain  27.000000  48000.000000                0                0
# 2  Germany  30.000000  54000.000000                0                1
# 3    Spain  38.000000  61000.000000                0                0
# 4  Germany  40.000000  63777.777778                0                1
# 5   France  35.000000  58000.000000                1                0
# 6    Spain  38.777778  52000.000000                0                0
# 7   France  48.000000  79000.000000                1                0
# 8  Germany  50.000000  83000.000000                0                1
# 9   France  37.000000  67000.000000                1                0
#
#    Country_codes_2
# 0                0
# 1                1
# 2                0
# 3                1
# 4                0
# 5                0
# 6                1
# 7                0
# 8                0
# 9                0

# %% [markdown]
# # 4. Splitting Test and Train Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train
# Out:
#    Country        Age        Salary  Country_codes
# 4  Germany  40.000000  63777.777778              1
# 9   France  37.000000  67000.000000              0
# 1    Spain  27.000000  48000.000000              2
# 6    Spain  38.777778  52000.000000              2
# 7   France  48.000000  79000.000000              0
# 3    Spain  38.000000  61000.000000              2
# 0   France  44.000000  72000.000000              0
# 5   France  35.000000  58000.000000              0

# %%
X_test
# Out:
#    Country   Age   Salary  Country_codes
# 2  Germany  30.0  54000.0              1
# 8  Germany  50.0  83000.0              1

# %%
y_train
# Out:
#   Purchased
# 4       Yes
# 9       Yes
# 1       Yes
# 6        No
# 7       Yes
# 3        No
# 0        No
# 5       Yes

# %%
y_test
# Out:
#   Purchased
# 2        No
# 8        No
